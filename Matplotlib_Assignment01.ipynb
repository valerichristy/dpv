# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=(iris.feature_names))
iris_df['target'] = pd.Series(iris.target)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
iris_df['target']= iris_df['target'].replace([0,1,2], ['setosa', 'versicolor', 'virginica'])

# %%
ax = pd.plotting.scatter_matrix(iris_df.iloc[:,0:4], alpha=0.4, figsize=(7,7), diagonal='hist', hist_kwds={'bins':10, 'color':'orange', 'edgecolor':'#FFFFFF'})

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-whitegrid')

# %%
sns.pairplot(iris_df, diag_kind="kde", hue='target',markers=["o", "s", "D"])
plt.legend=iris.target_names
